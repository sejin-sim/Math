# %% [markdown]
# <a href="https://colab.research.google.com/github/sejin-sim/Math/blob/main/1_%ED%99%95%EB%A5%A0%EB%A1%A0_%EA%B2%B0%ED%95%A9%ED%99%95%EB%A5%A0%EA%B3%BC_%EC%A1%B0%EA%B1%B4%EB%B6%80%ED%99%95%EB%A5%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 결합확률과 조건부확률
# ### 1) 예시
# 1. 범인 찾기 문제 : 살인 사건 발생 가정, 전체 용의자 목록(표본 공간)에서 누가 범인(선택된 표본)인가?
#  * 용의자 목록 = 남자 12명 + 여자 8명
#  * 사건 A =  남성인 용의자로만 이루어진 사건. P(A)는?
#  > $ P(A) = \dfrac{|A|}{|\Omega|} = \dfrac{12}{12 + 8} = \dfrac{12}{20} = 0.6 $
#  * 사건 A의 여집합 = 여성인 용의자로만 이루어진 사건
#  > $ P(A^C) = \dfrac{\left|A^C\right|}{|\Omega|} = \dfrac{8}{12 + 8} = \dfrac{8}{20} = 0.4$
#  * 사건 B = 머리카락이 긴 사람의 목록 (용의자 목록 = 머리 긴 10 + 머리 짧은 10)
#  > $ P(B) = \dfrac{|B|}{|\Omega|} = \dfrac{10}{10 + 10} = \dfrac{10}{20} = 0.5$
#  * 사건 B의 여집합 = 머리가 짧은 사람의 목록
#  > $ P(B^C) = \dfrac{\left|B^C\right|}{|\Omega|} = \dfrac{10}{10 + 10} = \dfrac{10}{20} = 0.5 $
#  * if, 머리긴 남자가 6명일 때 $ P(A|B) $
#  > $ P(A|B) = \dfrac{P(A, B)}{P(B)} = \dfrac{6/20}{10/20}  = \dfrac{6}{10} $
#  > ㄴ 사건 $A$와 사건 $B$는 서로 **독립** : 새로운 정보(사건 $B$)가 주어지든 주어지지 않든 남자가 범인일 확률은 변함없다.
#
# ### 2) 결합 확률
# 1. **결합확률(joint probability)** : 사건 $A$와 $B$가 동시에 발생할 확률
#  * 즉, 사건(명제/주장) $A$도 진실이고 사건(명제/주장) $B$도 진실이므로 사건 $A$와 $B$의 교집합의 확률을 계산하는 것
#  > $ P(A \cap B) \text{ or } P(A, B) $
# 2. 주변확률(marginal probability): 결합확률과 대비되는 개념으로 결합되지 않는 개별 사건의 확률 $P(A)$ 또는 $P(B)$
#
# ### 3) 조건부 확률
# 1. **조건부확률(conditional probability)** : $B$가 사실일 경우의 사건 $A$에 대한 확률
#  > $ P(A|B) = \dfrac{P(A,B)}{P(B)} $
# 2. 조건부 확률이 정의된 근거
#  > $ P(A|B) = \dfrac{P(A_\text{new})}{P(\Omega_\text{new})} = \dfrac{P(A,B)}{P(B)} $
# 3. 예시 : $P(A|B)$: 범인이 머리카락이 길다는 **사실**을 알게 되었을 때, 달라진(갱신된) "범인이 남자일 확률"
#
# ### 4) 독립
# 1. 사건 $A$와 사건 $B$의 결합확률의 값이 다음과 같은 관계가 성립하면 **두 사건 $A$와 $B$는 서로 독립(independent)**이라고 정의한다.
#  > $ P(A,B) = P(A)P(B) $
#  > $ P(A|B) = \dfrac{P(A,B)}{P(B)} = \dfrac{P(A)P(B)}{P(B)} = P(A) $
#  > ㄴ  $B$라는 사건이 발생하든 말든 사건 $A$에는 전혀 영향을 주지 않는 다는 것이다.
#
# ### 5) 원인과 결과, 근거와 추론, 가정과 조건부 결론
# 1. 조건부확률 $P(A|B)$에서 사건(주장/명제) $B$, $A$
#  > * $ P(A,B) = P(A|B) P(B) $
#  > * $ P(A,B,C,D) = P(A,B|C,D)P(C,D) $
# 2. 증명
#  >
# $
# \begin{aligned}
# P(A,B,C)
# &= P(A \cap B \cap C) \\
# &= P(A \cap (B \cap C)) \\
# &= P(A|B \cap C)P(B \cap C) \\
# &= P(A|B,C)P(B,C)
# \end{aligned}
# $
#
# ###6) 사슬 법칙
# 1. 사슬 법칙(chain rule) : 조건부확률과 결합확률의 관계를 확장하면 복수의 사건 $X_1, X_2, \dots, X_N$에 대한 조건부 확률을 다음처럼 쓸 수 있다.
#  > $
# \begin{aligned}
# P(X_1, X_2)           &= P(X_1) P(X_2 | X_1) \\
# P(X_1, X_2, X_3)      &= P(X_3 | X_1, X_2) P(X_1, X_2) \\
#                       &= P(X_1) P(X_2 | X_1) P(X_3 | X_1, X_2) \\
# P(X_1, X_2, X_3, X_4) &= P(X_4 | X_1, X_2, X_3) P(X_1, X_2, X_3) \\
#                       &= P(X_1) P(X_2 | X_1) P(X_3 | X_1, X_2) P(X_4 | X_1, X_2, X_3) \\
#                       & \vdots  \\
# P(X_1, \dots, X_N)    &= P(X_1) \prod_{i=2}^{N} P( X_{i} | X_1, \dots X_{i-1})
# \end{aligned}
# $
#
# ### 7) 확률변수
# 1. 확률변수(random variable) : 확률적인 숫자 값을 출력하는 변수
# 2. 예시 : 위의 범인 찾기 문제에서는 두 확률변수 $X$, $Y$를 정의할 수 있다. 확률변수 $X$는 성별을 나타내고 확률변수 $Y$는 머리카락이 긴지 짧은지를 나타낸다.
#  > * $X=0$인 경우가 사건 $A$ (남자인 사건)
#  > * $X=1$인 경우가 사건 $A^C$ (여자인 사건)
#  > * $Y=0$인 경우가 사건 $B$ (머리카락이 긴 사건)
#  > * $Y=1$인 경우가 사건 $B^C$ (머리카락이 짧은 사건)

# %%
# 이산확률 모형

from pgmpy.factors.discrete import JointProbabilityDistribution as JPD
import numpy as np

# JointProbabilityDistribution(variables, cardinality, values)
# * `variables`: 확률변수의 이름 문자열의 리스트. 정의하려는 확률변수가 하나인 경우에도 리스트로 넣어야 한다.
# * `cardinality`: 각 확률변수의 표본 혹은 배타적 사건의 수의 리스트
# * `values`: 확률변수의 모든 표본(조합)에 대한 (결합)확률값의 리스트

print("* 확률 변수 X(A 사건) *")
px = JPD(['X'], [2], np.array([12, 8]) / 20)
print(px)

print("\n* X와 Y의 결합확률 *")
pxy = JPD(['X', 'Y'], [2, 2], np.array([3, 9, 7, 1]) / 20)
print(pxy)

print("\n* 결합확률로 부터의 주변확률 P(A), P(A^C) *")
pmx = pxy.marginalize(['Y'], inplace=False)
print(pmx)
# `marginalize()` 메서드는 인수로 받은 확률변수를 주변화(marginalize)하여 나머지 확률변수에 대한 주변확률분포를 구한다

print("\n* 결합확률로 부터의 주변확률 P(B), P(B^C) *")
py = pxy.marginal_distribution(['Y'], inplace=False)
print(py)

print("\n* 결합확률로부터 조건부확률 P(B|A), $P(B^C|A) *")
py_on_x0 = pxy.conditional_distribution([('X', 0)], inplace=False)  # 사건 A에 대한 조건부확률
print(py_on_x0)
# `conditional_distribution()` 메서드를 사용하면 어떤 확률변수가 어떤 사건이 되는 조건에 대해 조건부확률값을 계산한다.

print("\n* 결합확률로부터 조건부확률 P(B|A^C), $P(B^C|A^C) *")
py_on_x1 = pxy.conditional_distribution([('X', 1)], inplace=False)
print(py_on_x1)

print("\n* 결합확률로부터 조건부확률 P(A|B), $P(A^C|B) *")
px_on_y0 = pxy.conditional_distribution([('Y', 0)], inplace=False)  # 사건 B에 대한 조건부확률
print(px_on_y0)

print("\ncheck_independence(['X'], ['Y'] =", pxy.check_independence(['X'], ['Y']))
# check_independence() 메서드를 이용하면 두 확률변수 간의 독립도 확인할 수 있다.

print("\n* px x py *")
print(px * py)
print("\n* pxy *")
print(pxy)
# 두 개의 JointProbabilityDistribution 객체끼리 곱하면 두 분포가 독립이라는 가정하에 결합확률을 구한다. 이 값과 원래의 결합확률을 비교하면 독립이 아니라는 것을 알 수 있다.
# Out:
# * 확률 변수 X(A 사건) *
# +------+--------+
# | X    |   P(X) |
# +======+========+
# | X(0) | 0.6000 |
# +------+--------+
# | X(1) | 0.4000 |
# +------+--------+
#
# * X와 Y의 결합확률 *
# +------+------+----------+
# | X    | Y    |   P(X,Y) |
# +======+======+==========+
# | X(0) | Y(0) |   0.1500 |
# +------+------+----------+
# | X(0) | Y(1) |   0.4500 |
# +------+------+----------+
# | X(1) | Y(0) |   0.3500 |
# +------+------+----------+
# | X(1) | Y(1) |   0.0500 |
# +------+------+----------+
#
# * 결합확률로 부터의 주변확률 P(A), P(A^C) *
# +------+--------+
# | X    |   P(X) |
# +======+========+
# | X(0) | 0.6000 |
# +------+--------+
# | X(1) | 0.4000 |
# +------+--------+
#
# * 결합확률로 부터의 주변확률 P(B), P(B^C) *
# +------+--------+
# | Y    |   P(Y) |
# +======+========+
# | Y(0) | 0.5000 |
# +------+--------+
# | Y(1) | 0.5000 |
# +------+--------+
#
# * 결합확률로부터 조건부확률 P(B|A), $P(B^C|A) *
# +------+--------+
# | Y    |   P(Y) |
# +======+========+
# | Y(0) | 0.2500 |
# +------+--------+
# ...
